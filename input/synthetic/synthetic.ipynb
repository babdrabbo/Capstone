# %%
import sys
import typing
import inspect
import itertools
import numpy as np
from random import randint, shuffle, getrandbits
from collections import Counter, defaultdict
from typing import Any, Callable, Optional
from itertools import combinations
from abc import ABC, abstractmethod
from collections.abc import Iterable
from matplotlib import pyplot as plt
from types import NoneType, UnionType
from numpy.random import random, choice, normal, triangular
from typing import Union, TypeVar, Optional, get_origin, get_args

sys.path.append('../../src')
from ARCSolver.hypothesis import Hypothesis
from helpers.task import Task
from helpers.task_vis import *
from priors.primitives import *
from exegraph.exegraph import *

# %%
def get_task(category, id):
    input_dir = "../../input"
    return Task(f'{input_dir}/{category}/{id}.json')

# %%
f"{1:03}"
# Out:
# '001'

# %%
n_synthetic_tasks = 2
synthetic_tasks = [get_task("synthetic", f"s{id:02}") for id in range(n_synthetic_tasks)]
for t in synthetic_tasks:
    plot_task_sample(t)
# Out:
# type(axs): <class 'numpy.ndarray'>
# type(axs): <class 'numpy.ndarray'>
